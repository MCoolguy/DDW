# %% [markdown]
# # Week 3 Extra Problem Set

# %%
# %load_ext nb_mypy
# %nb_mypy On

# %% [markdown]
# Q1. Implement a function `sum(array)` to sum the element of a list. This function make use of another recursive function `sum(array, index, sum)`. The second function uses recursion to iteratively sum the element of a list given by the index and keeps track of the sum using the third argument.

# %%
from typing import TypeAlias
ListNumber: TypeAlias = list[int|float]
Number: TypeAlias = int|float

# %%
def sum(array: ListNumber) -> Number:
    return sum_iter(array, 0, 0)

def sum_iter(array: ListNumber, index: int, total: Number) -> Number:
    if index == len(array):
        ###
        ### YOUR CODE HERE
        ###
    else:
        ###
        ### YOUR CODE HERE
        ###

# %%
assert sum([1, 2, 3, 4, 5]) == 15

# %% [markdown]
# Q2. Write a function `factorial(n)` which calls a second function `fact_iter(product, counter, max_count)`. The second function implements iteration using recursive call to compute the factorial n.
#
# Note: In what way is this function different from that in your Cohort problem?

# %%
def factorial(n: int) -> int:
    return fact_iter(1, 1, n)

def fact_iter(product: int, counter: int, max_count: int)-> int:
    if counter > max_count:
        ###
        ### YOUR CODE HERE
        ###
    else:
        ###
        ### YOUR CODE HERE
        ###

# %%
assert factorial(5) == 120

# %% [markdown]
# Q3. In this question and the next one, we are going to implement a function `count_change(amount)` which computes the number of permutation of possible change that is equivalent to amount. Given coins of 10c, 20c, 50c, and 100c, the functions returns the possible number that amount can be formed using those coins. Use recursion in your solution.
#
# Assume that kinds of coins is sorted from the largest to the smallest, i.e. 100c, 50c, 20c, 10c.
#
# Write a function `first_denomination(kinds_of_coins)` which takes in how many kinds of coins and returns the first denomination. For example, if there are four kinds, it should return 100. If there are three kinds, it should return 50c. If there is only one kind, it should return 10c.

# %%
def first_denomination(kinds_of_coins: int) -> int:
    ###
    ### YOUR CODE HERE
    ###

# %%
assert first_denomination(4) == 100
assert first_denomination(3) == 50
assert first_denomination(2) == 20
assert first_denomination(1) == 10

# %% [markdown]
# Q4. Continuing from the last question, write a function `cc(amount, kinds_of_coins)` which returns the number of possible combinations for amount given the number of kinds of coins in the second argument. See test cases for example.
#
# Base case:
# - if amount is 0, we should count as one way to make change for amount.
# - if amount is less than 0, we should count that as 0 ways to make change for amount.
# - if kinds of coins is 0, we should count that as 0 ways to make change for amount.
#
# Recursive case:
# The number of ways to make change for amount $a$ using $n$ coins equals:
# - the number of ways to make change for amount $a$ using all but the first kind of coins, plus
# - the number of ways to make change for amount $a-d$ using all $n$ kinds of coins, where $d$ is the denomination of the first kind of coin.
#
# Note: Make use of the previous function `first_denomination()` when you need to get $d$.

# %%
def count_change(amount: int) -> int:
    return cc(amount, 4)

def cc(amount: int, kinds_of_coins: int) -> int:
    ###
    ### YOUR CODE HERE
    ###

# %%
assert count_change(10) == 1 
assert count_change(20) == 2
assert count_change(30) == 2
assert count_change(100) == 11
assert count_change(500) == 341

# %% [markdown]
# Q5. Write a function to compute exponentiation $b^n$. Exponentiation can be defined recursively using the following.
#
# $$b^n = b \times b^{n-1}$$
# $$b^0 = 1$$

# %%
def expt(b: Number, n: int) -> Number:
    ###
    ### YOUR CODE HERE
    ###

# %%
assert expt(2, 3) == 8
assert expt(3, 3) == 27

# %% [markdown]
# Q6. We can speed up exponentiation if $n$ are powers of 2. We can reduce the number of multiplication in this way.
#
# $$b^2 = b \times b$$
# $$b^4 = b^2 \times b^2$$
# $$b^8 = b^4 \times b^4$$
#
# In this way, when $n$ is even, we have
# $$b^n = (b^{n/2})^2$$
#
# and when $n$ is odd, we have
# $$b^n = b\times b^{n-1}$$
#
# Note: Use the previously defined `square()` function instead of applying `**` operator in Python.

# %%
def square(x: Number) -> Number:
    return x * x

# %%
def fast_expt(b: Number, n: int) -> Number:
    ###
    ### YOUR CODE HERE
    ###

# %%
assert fast_expt(2, 3) == 8
assert fast_expt(3, 3) == 27
assert fast_expt(2, 10) == 1024

# %% [markdown]
# Q7. Write a function `bin(n)` which convert an integer into a binary string representation. There are two base cases when `n=0` and `n=1` both has 0 and 1 string representation. For numbers larger than 1, we can do it recursively.
# `concatenate(bin(n//2) , bin(n%2))`
# where the function concetate joins the two binary string together.

# %%
def bin(n: int) -> str:
    ###
    ### YOUR CODE HERE
    ###
    pass

# %%
assert bin(0) == '0'
assert bin(1) == '1'
assert bin(2) == '10'
assert bin(3) == '11'
assert bin(5) == '101'
assert bin(8) == '1000'
assert bin(10) == '1010'
